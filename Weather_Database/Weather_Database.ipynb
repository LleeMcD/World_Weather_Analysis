# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import csv

# %%
# Create a set of random latitude and longitude combinations.
## Create a set of 2000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
 # Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Import the requests library.
import requests

# Import the API key.
from config_1 import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e2c0addb2379ad604f19c90b9428be2

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        weather_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": weather_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | macia
# Processing Record 2 of Set 1 | bubaque
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | upernavik
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 1 | khatanga
# Processing Record 8 of Set 1 | chokurdakh
# Processing Record 9 of Set 1 | hithadhoo
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | fortuna
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | dikson
# Processing Record 15 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | college
# Processing Record 18 of Set 1 | gornoye loo
# Processing Record 19 of Set 1 | san patricio
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | pangody
# Processing Record 22 of Set 1 | bengkulu
# Processing Record 23 of Set 1 | jasper
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | koslan
# Processing Record 26 of Set 1 | burica
# City not found. Skipping...
# Processing Record 27 of Set 1 | saskylakh
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | kruisfontein
# Processing Record 30 of Set 1 | qaanaaq
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | georgetown
# Processing Record 33 of Set 1 | gizo
# Processing Record 34 of Set 1 | mangrol
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | tasiilaq
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | batticaloa
# Processing Record 40 of Set 1 | high prairie
# Processing Record 41 of Set 1 | suzun
# Processing Record 42 of Set 1 | honiara
# Processing Record 43 of Set 1 | muros
# Processing Record 44 of Set 1 | puerto madryn
# Processing Record 45 of Set 1 | nanortalik
# Processing Record 46 of Set 1 | sao felix do xingu
# Processing Record 47 of Set 1 | cotmeana
# Processing Record 48 of Set 1 | palmer
# Processing Record 49 of Set 1 | hervey bay
# Processing Record 50 of Set 1 | cap malheureux
# Processing Record 1 of Set 2 | lifford
# Processing Record 2 of Set 2 | neenah
# Processing Record 3 of Set 2 | atuona
# Processing Record 4 of Set 2 | puerto ayora
# Processing Record 5 of Set 2 | souillac
# Processing Record 6 of Set 2 | santa rosa
# Processing Record 7 of Set 2 | cayenne
# Processing Record 8 of Set 2 | jiwani
# Processing Record 9 of Set 2 | mar del plata
# Processing Record 10 of Set 2 | kalulushi
# Processing Record 11 of Set 2 | nara
# Processing Record 12 of Set 2 | saint-philippe
# Processing Record 13 of Set 2 | codrington
# Processing Record 14 of Set 2 | amahai
# Processing Record 15 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 16 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 2 | waddan
# Processing Record 18 of Set 2 | snasa
# Processing Record 19 of Set 2 | tiznit
# Processing Record 20 of Set 2 | san andres
# Processing Record 21 of Set 2 | saurimo
# Processing Record 22 of Set 2 | gunjur
# Processing Record 23 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 24 of Set 2 | puri
# Processing Record 25 of Set 2 | roma
# Processing Record 26 of Set 2 | westport
# Processing Record 27 of Set 2 | anori
# Processing Record 28 of Set 2 | aklavik
# Processing Record 29 of Set 2 | esperance
# Processing Record 30 of Set 2 | sao filipe
# Processing Record 31 of Set 2 | new norfolk
# Processing Record 32 of Set 2 | gulshat
# City not found. Skipping...
# Processing Record 33 of Set 2 | havre-saint-pierre
# Processing Record 34 of Set 2 | nome
# Processing Record 35 of Set 2 | butaritari
# Processing Record 36 of Set 2 | bethel
# Processing Record 37 of Set 2 | faanui
# Processing Record 38 of Set 2 | bathsheba
# Processing Record 39 of Set 2 | egvekinot
# Processing Record 40 of Set 2 | nouadhibou
# Processing Record 41 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 2 | kurilsk
# Processing Record 43 of Set 2 | ixtapa
# Processing Record 44 of Set 2 | port alfred
# Processing Record 45 of Set 2 | nabire
# Processing Record 46 of Set 2 | port elizabeth
# Processing Record 47 of Set 2 | mehamn
# Processing Record 48 of Set 2 | provideniya
# Processing Record 49 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 2 | cloquet
# Processing Record 1 of Set 3 | clyde river
# Processing Record 2 of Set 3 | mina
# Processing Record 3 of Set 3 | comodoro rivadavia
# Processing Record 4 of Set 3 | qiongshan
# Processing Record 5 of Set 3 | tiksi
# Processing Record 6 of Set 3 | cidreira
# Processing Record 7 of Set 3 | sawakin
# Processing Record 8 of Set 3 | gubkinskiy
# Processing Record 9 of Set 3 | east london
# Processing Record 10 of Set 3 | chuy
# Processing Record 11 of Set 3 | avarua
# Processing Record 12 of Set 3 | yebaishou
# Processing Record 13 of Set 3 | matam
# Processing Record 14 of Set 3 | norman wells
# Processing Record 15 of Set 3 | hilo
# Processing Record 16 of Set 3 | jiexiu
# Processing Record 17 of Set 3 | gohad
# Processing Record 18 of Set 3 | tura
# Processing Record 19 of Set 3 | ust-tsilma
# Processing Record 20 of Set 3 | nikolskoye
# Processing Record 21 of Set 3 | isangel
# Processing Record 22 of Set 3 | ondjiva
# Processing Record 23 of Set 3 | quesnel
# Processing Record 24 of Set 3 | guerrero negro
# Processing Record 25 of Set 3 | tari
# Processing Record 26 of Set 3 | olafsvik
# Processing Record 27 of Set 3 | port blair
# Processing Record 28 of Set 3 | maymanak
# City not found. Skipping...
# Processing Record 29 of Set 3 | ponta delgada
# Processing Record 30 of Set 3 | wanning
# Processing Record 31 of Set 3 | tokoroa
# Processing Record 32 of Set 3 | okhotsk
# Processing Record 33 of Set 3 | kushima
# Processing Record 34 of Set 3 | torbay
# Processing Record 35 of Set 3 | ilulissat
# Processing Record 36 of Set 3 | abu samrah
# Processing Record 37 of Set 3 | puerto del rosario
# Processing Record 38 of Set 3 | mahebourg
# Processing Record 39 of Set 3 | lagoa vermelha
# Processing Record 40 of Set 3 | kencong
# Processing Record 41 of Set 3 | hasaki
# Processing Record 42 of Set 3 | falealupo
# City not found. Skipping...
# Processing Record 43 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 3 | dudinka
# Processing Record 45 of Set 3 | antofagasta
# Processing Record 46 of Set 3 | lebu
# Processing Record 47 of Set 3 | cabo san lucas
# Processing Record 48 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 3 | riorges
# Processing Record 50 of Set 3 | kuldiga
# Processing Record 1 of Set 4 | denpasar
# Processing Record 2 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 4 | rognan
# Processing Record 4 of Set 4 | arraial do cabo
# Processing Record 5 of Set 4 | geraldton
# Processing Record 6 of Set 4 | imbituba
# Processing Record 7 of Set 4 | bambous virieux
# Processing Record 8 of Set 4 | castlemaine
# Processing Record 9 of Set 4 | lasa
# Processing Record 10 of Set 4 | kirakira
# Processing Record 11 of Set 4 | zhuhai
# Processing Record 12 of Set 4 | grindavik
# Processing Record 13 of Set 4 | carnarvon
# Processing Record 14 of Set 4 | kodiak
# Processing Record 15 of Set 4 | xining
# Processing Record 16 of Set 4 | asau
# Processing Record 17 of Set 4 | mendi
# Processing Record 18 of Set 4 | indramayu
# Processing Record 19 of Set 4 | ivdel
# Processing Record 20 of Set 4 | oranjemund
# Processing Record 21 of Set 4 | hofn
# Processing Record 22 of Set 4 | vila franca do campo
# Processing Record 23 of Set 4 | linxia
# Processing Record 24 of Set 4 | jiaojiang
# Processing Record 25 of Set 4 | lazaro cardenas
# Processing Record 26 of Set 4 | rio grande
# Processing Record 27 of Set 4 | hopelchen
# Processing Record 28 of Set 4 | shakawe
# Processing Record 29 of Set 4 | colac
# Processing Record 30 of Set 4 | aksarka
# Processing Record 31 of Set 4 | mastic beach
# Processing Record 32 of Set 4 | narsaq
# Processing Record 33 of Set 4 | viransehir
# Processing Record 34 of Set 4 | sydney
# Processing Record 35 of Set 4 | merauke
# Processing Record 36 of Set 4 | bambari
# Processing Record 37 of Set 4 | shitanjing
# Processing Record 38 of Set 4 | san quintin
# Processing Record 39 of Set 4 | qui nhon
# Processing Record 40 of Set 4 | tapaua
# City not found. Skipping...
# Processing Record 41 of Set 4 | bredasdorp
# Processing Record 42 of Set 4 | taoudenni
# Processing Record 43 of Set 4 | karachi
# Processing Record 44 of Set 4 | paita
# Processing Record 45 of Set 4 | kahului
# Processing Record 46 of Set 4 | dingle
# Processing Record 47 of Set 4 | cosala
# Processing Record 48 of Set 4 | stoyba
# City not found. Skipping...
# Processing Record 49 of Set 4 | maragogi
# Processing Record 50 of Set 4 | labuhan
# Processing Record 1 of Set 5 | ancud
# Processing Record 2 of Set 5 | vardo
# Processing Record 3 of Set 5 | lagoa
# Processing Record 4 of Set 5 | seinajoki
# Processing Record 5 of Set 5 | panguna
# Processing Record 6 of Set 5 | sao joao da barra
# Processing Record 7 of Set 5 | sofiysk
# City not found. Skipping...
# Processing Record 8 of Set 5 | victoria
# Processing Record 9 of Set 5 | wajir
# Processing Record 10 of Set 5 | portland
# Processing Record 11 of Set 5 | prince rupert
# Processing Record 12 of Set 5 | thompson
# Processing Record 13 of Set 5 | rudna
# Processing Record 14 of Set 5 | mitu
# Processing Record 15 of Set 5 | bandarbeyla
# Processing Record 16 of Set 5 | salalah
# Processing Record 17 of Set 5 | bereda
# Processing Record 18 of Set 5 | porto santo
# Processing Record 19 of Set 5 | barrow
# Processing Record 20 of Set 5 | banda aceh
# Processing Record 21 of Set 5 | bath
# Processing Record 22 of Set 5 | rosetta
# Processing Record 23 of Set 5 | ankang
# Processing Record 24 of Set 5 | ostrovnoy
# Processing Record 25 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 5 | saldanha
# Processing Record 27 of Set 5 | whitehorse
# Processing Record 28 of Set 5 | ribeira grande
# Processing Record 29 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 5 | ried
# Processing Record 31 of Set 5 | hurricane
# Processing Record 32 of Set 5 | mansalay
# Processing Record 33 of Set 5 | noshiro
# Processing Record 34 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 35 of Set 5 | shestakovo
# Processing Record 36 of Set 5 | rongotea
# Processing Record 37 of Set 5 | ninh binh
# Processing Record 38 of Set 5 | jaguarari
# Processing Record 39 of Set 5 | bay city
# Processing Record 40 of Set 5 | tuktoyaktuk
# Processing Record 41 of Set 5 | saint-augustin
# Processing Record 42 of Set 5 | sistranda
# Processing Record 43 of Set 5 | san lawrenz
# Processing Record 44 of Set 5 | lavrentiya
# Processing Record 45 of Set 5 | chitral
# Processing Record 46 of Set 5 | pevek
# Processing Record 47 of Set 5 | mulege
# Processing Record 48 of Set 5 | leshukonskoye
# Processing Record 49 of Set 5 | yellowknife
# Processing Record 50 of Set 5 | kaitangata
# Processing Record 1 of Set 6 | auki
# Processing Record 2 of Set 6 | greenville
# Processing Record 3 of Set 6 | axim
# Processing Record 4 of Set 6 | nizhnevartovsk
# Processing Record 5 of Set 6 | skibbereen
# Processing Record 6 of Set 6 | sioux lookout
# Processing Record 7 of Set 6 | vestmannaeyjar
# Processing Record 8 of Set 6 | rio gallegos
# Processing Record 9 of Set 6 | vernon
# Processing Record 10 of Set 6 | maneadero
# Processing Record 11 of Set 6 | broken hill
# Processing Record 12 of Set 6 | bowen
# Processing Record 13 of Set 6 | sri aman
# Processing Record 14 of Set 6 | krasnoselkup
# Processing Record 15 of Set 6 | spokane
# Processing Record 16 of Set 6 | husavik
# Processing Record 17 of Set 6 | ambilobe
# Processing Record 18 of Set 6 | airai
# Processing Record 19 of Set 6 | cortez
# Processing Record 20 of Set 6 | manakara
# Processing Record 21 of Set 6 | hirado
# Processing Record 22 of Set 6 | lompoc
# Processing Record 23 of Set 6 | hlotse
# Processing Record 24 of Set 6 | lere
# Processing Record 25 of Set 6 | humen
# Processing Record 26 of Set 6 | ponta do sol
# Processing Record 27 of Set 6 | cape coast
# Processing Record 28 of Set 6 | san cristobal
# Processing Record 29 of Set 6 | taltal
# Processing Record 30 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 6 | gua musang
# Processing Record 32 of Set 6 | shache
# Processing Record 33 of Set 6 | praya
# Processing Record 34 of Set 6 | saint-francois
# Processing Record 35 of Set 6 | sao jose da coroa grande
# Processing Record 36 of Set 6 | birao
# Processing Record 37 of Set 6 | salawagan
# Processing Record 38 of Set 6 | marzuq
# Processing Record 39 of Set 6 | kavaratti
# Processing Record 40 of Set 6 | kholmogory
# Processing Record 41 of Set 6 | dom pedrito
# Processing Record 42 of Set 6 | kaa-khem
# Processing Record 43 of Set 6 | alofi
# Processing Record 44 of Set 6 | shetpe
# Processing Record 45 of Set 6 | pimentel
# Processing Record 46 of Set 6 | panaba
# Processing Record 47 of Set 6 | saint george
# Processing Record 48 of Set 6 | hays
# Processing Record 49 of Set 6 | sibolga
# Processing Record 50 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 7 | manzhouli
# Processing Record 2 of Set 7 | hattiesburg
# Processing Record 3 of Set 7 | atikokan
# Processing Record 4 of Set 7 | itarema
# Processing Record 5 of Set 7 | hami
# Processing Record 6 of Set 7 | umm lajj
# Processing Record 7 of Set 7 | cove
# Processing Record 8 of Set 7 | vila velha
# Processing Record 9 of Set 7 | tuy hoa
# Processing Record 10 of Set 7 | harper
# Processing Record 11 of Set 7 | havelock
# Processing Record 12 of Set 7 | pochutla
# Processing Record 13 of Set 7 | borisoglebskiy
# Processing Record 14 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 7 | gollere
# City not found. Skipping...
# Processing Record 16 of Set 7 | alberton
# Processing Record 17 of Set 7 | eureka
# Processing Record 18 of Set 7 | coihaique
# Processing Record 19 of Set 7 | malia
# Processing Record 20 of Set 7 | castro
# Processing Record 21 of Set 7 | arona
# Processing Record 22 of Set 7 | te anau
# Processing Record 23 of Set 7 | nuuk
# Processing Record 24 of Set 7 | trofors
# Processing Record 25 of Set 7 | catanzaro
# Processing Record 26 of Set 7 | bemidji
# Processing Record 27 of Set 7 | mitsamiouli
# Processing Record 28 of Set 7 | makakilo city
# Processing Record 29 of Set 7 | gat
# Processing Record 30 of Set 7 | manggar
# Processing Record 31 of Set 7 | lincoln
# Processing Record 32 of Set 7 | raleigh
# Processing Record 33 of Set 7 | along
# Processing Record 34 of Set 7 | chichli
# Processing Record 35 of Set 7 | odweyne
# Processing Record 36 of Set 7 | morant bay
# Processing Record 37 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 7 | tual
# Processing Record 39 of Set 7 | leningradskiy
# Processing Record 40 of Set 7 | alyangula
# Processing Record 41 of Set 7 | keti bandar
# Processing Record 42 of Set 7 | severo-kurilsk
# Processing Record 43 of Set 7 | novorzhev
# Processing Record 44 of Set 7 | mount isa
# Processing Record 45 of Set 7 | baoqing
# Processing Record 46 of Set 7 | zuwarah
# Processing Record 47 of Set 7 | bolshiye uki
# City not found. Skipping...
# Processing Record 48 of Set 7 | santa cruz
# Processing Record 49 of Set 7 | hoshiarpur
# Processing Record 50 of Set 7 | port macquarie
# Processing Record 1 of Set 8 | ocean springs
# Processing Record 2 of Set 8 | shevchenkove
# Processing Record 3 of Set 8 | le mars
# Processing Record 4 of Set 8 | rio verde de mato grosso
# Processing Record 5 of Set 8 | vostok
# Processing Record 6 of Set 8 | cherskiy
# Processing Record 7 of Set 8 | mizan teferi
# Processing Record 8 of Set 8 | boende
# Processing Record 9 of Set 8 | charlestown
# Processing Record 10 of Set 8 | hirara
# Processing Record 11 of Set 8 | dunedin
# Processing Record 12 of Set 8 | talin
# Processing Record 13 of Set 8 | ballina
# Processing Record 14 of Set 8 | belyy yar
# Processing Record 15 of Set 8 | cockburn town
# Processing Record 16 of Set 8 | vao
# Processing Record 17 of Set 8 | viedma
# Processing Record 18 of Set 8 | ko samui
# Processing Record 19 of Set 8 | nemuro
# Processing Record 20 of Set 8 | fukue
# Processing Record 21 of Set 8 | vung tau
# Processing Record 22 of Set 8 | kokoda
# Processing Record 23 of Set 8 | plettenberg bay
# Processing Record 24 of Set 8 | sarankhola
# Processing Record 25 of Set 8 | russell
# Processing Record 26 of Set 8 | pedernales
# Processing Record 27 of Set 8 | zhezkazgan
# Processing Record 28 of Set 8 | malinovoye ozero
# Processing Record 29 of Set 8 | ouango
# Processing Record 30 of Set 8 | wau
# Processing Record 31 of Set 8 | huarmey
# Processing Record 32 of Set 8 | half moon bay
# Processing Record 33 of Set 8 | ngunguru
# Processing Record 34 of Set 8 | kupang
# Processing Record 35 of Set 8 | liniere
# City not found. Skipping...
# Processing Record 36 of Set 8 | grand gaube
# Processing Record 37 of Set 8 | deputatskiy
# Processing Record 38 of Set 8 | valparaiso
# Processing Record 39 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 40 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 41 of Set 8 | mandiana
# Processing Record 42 of Set 8 | luderitz
# Processing Record 43 of Set 8 | rocha
# Processing Record 44 of Set 8 | macau
# Processing Record 45 of Set 8 | shimoda
# Processing Record 46 of Set 8 | christchurch
# Processing Record 47 of Set 8 | coquimbo
# Processing Record 48 of Set 8 | pyinmana
# Processing Record 49 of Set 8 | carballo
# Processing Record 50 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 9 | sharan
# Processing Record 2 of Set 9 | manati
# Processing Record 3 of Set 9 | aykhal
# Processing Record 4 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 9 | ruteng
# Processing Record 6 of Set 9 | mayo
# Processing Record 7 of Set 9 | muroto
# Processing Record 8 of Set 9 | bukit bakri
# City not found. Skipping...
# Processing Record 9 of Set 9 | port townsend
# Processing Record 10 of Set 9 | newport
# Processing Record 11 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 12 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 13 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 9 | poum
# Processing Record 15 of Set 9 | avera
# Processing Record 16 of Set 9 | purpe
# Processing Record 17 of Set 9 | dawlatabad
# Processing Record 18 of Set 9 | kulhudhuffushi
# Processing Record 19 of Set 9 | smolensk
# Processing Record 20 of Set 9 | ikwiriri
# Processing Record 21 of Set 9 | phan thiet
# Processing Record 22 of Set 9 | kudahuvadhoo
# Processing Record 23 of Set 9 | mandalay
# Processing Record 24 of Set 9 | harrisonburg
# Processing Record 25 of Set 9 | yerbogachen
# Processing Record 26 of Set 9 | charters towers
# Processing Record 27 of Set 9 | hambantota
# Processing Record 28 of Set 9 | necochea
# Processing Record 29 of Set 9 | lubartow
# Processing Record 30 of Set 9 | dayong
# Processing Record 31 of Set 9 | goderich
# Processing Record 32 of Set 9 | amambai
# Processing Record 33 of Set 9 | thinadhoo
# Processing Record 34 of Set 9 | zolotukhino
# Processing Record 35 of Set 9 | raudeberg
# Processing Record 36 of Set 9 | puerto madero
# Processing Record 37 of Set 9 | rodrigues alves
# Processing Record 38 of Set 9 | irbit
# Processing Record 39 of Set 9 | blagoyevo
# Processing Record 40 of Set 9 | conceicao da barra
# Processing Record 41 of Set 9 | katsuura
# Processing Record 42 of Set 9 | mingshui
# Processing Record 43 of Set 9 | pacasmayo
# Processing Record 44 of Set 9 | umm kaddadah
# Processing Record 45 of Set 9 | djibo
# Processing Record 46 of Set 9 | kirishi
# Processing Record 47 of Set 9 | gobabis
# Processing Record 48 of Set 9 | moree
# Processing Record 49 of Set 9 | gabu
# Processing Record 50 of Set 9 | yaring
# Processing Record 1 of Set 10 | araguaina
# Processing Record 2 of Set 10 | constitucion
# Processing Record 3 of Set 10 | tekirdag
# Processing Record 4 of Set 10 | karla
# Processing Record 5 of Set 10 | klyuchi
# Processing Record 6 of Set 10 | bremervorde
# Processing Record 7 of Set 10 | port lincoln
# Processing Record 8 of Set 10 | tilichiki
# Processing Record 9 of Set 10 | sundargarh
# Processing Record 10 of Set 10 | birjand
# Processing Record 11 of Set 10 | hammerfest
# Processing Record 12 of Set 10 | san pedro
# Processing Record 13 of Set 10 | piacabucu
# Processing Record 14 of Set 10 | nizwa
# Processing Record 15 of Set 10 | fairbanks
# Processing Record 16 of Set 10 | longyearbyen
# Processing Record 17 of Set 10 | kavieng
# Processing Record 18 of Set 10 | henties bay
# Processing Record 19 of Set 10 | san angelo
# Processing Record 20 of Set 10 | saint anthony
# Processing Record 21 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 10 | ocampo
# Processing Record 23 of Set 10 | diapaga
# Processing Record 24 of Set 10 | ofunato
# Processing Record 25 of Set 10 | hobo
# Processing Record 26 of Set 10 | manokwari
# Processing Record 27 of Set 10 | laibin
# Processing Record 28 of Set 10 | giyani
# Processing Record 29 of Set 10 | prijedor
# Processing Record 30 of Set 10 | iqaluit
# Processing Record 31 of Set 10 | kouroussa
# Processing Record 32 of Set 10 | mandapam
# Processing Record 33 of Set 10 | oistins
# Processing Record 34 of Set 10 | vila
# Processing Record 35 of Set 10 | trairi
# Processing Record 36 of Set 10 | roros
# Processing Record 37 of Set 10 | tanete
# Processing Record 38 of Set 10 | novo mesto
# Processing Record 39 of Set 10 | upington
# Processing Record 40 of Set 10 | pila
# Processing Record 41 of Set 10 | boa vista
# Processing Record 42 of Set 10 | sarakhs
# Processing Record 43 of Set 10 | huancabamba
# Processing Record 44 of Set 10 | adrar
# Processing Record 45 of Set 10 | letlhakane
# Processing Record 46 of Set 10 | tankara
# Processing Record 47 of Set 10 | hauge
# Processing Record 48 of Set 10 | riverton
# Processing Record 49 of Set 10 | ati
# Processing Record 50 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 1 of Set 11 | tuatapere
# Processing Record 2 of Set 11 | likasi
# Processing Record 3 of Set 11 | lata
# Processing Record 4 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 5 of Set 11 | dong hoi
# Processing Record 6 of Set 11 | waingapu
# Processing Record 7 of Set 11 | workington
# Processing Record 8 of Set 11 | kismayo
# Processing Record 9 of Set 11 | belis
# Processing Record 10 of Set 11 | xico
# Processing Record 11 of Set 11 | anadyr
# Processing Record 12 of Set 11 | cazaje
# City not found. Skipping...
# Processing Record 13 of Set 11 | havoysund
# Processing Record 14 of Set 11 | hinton
# Processing Record 15 of Set 11 | aswan
# Processing Record 16 of Set 11 | sychevka
# Processing Record 17 of Set 11 | tondano
# Processing Record 18 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 19 of Set 11 | halifax
# Processing Record 20 of Set 11 | roald
# Processing Record 21 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 22 of Set 11 | fussen
# Processing Record 23 of Set 11 | mantua
# Processing Record 24 of Set 11 | atbasar
# Processing Record 25 of Set 11 | warmbad
# Processing Record 26 of Set 11 | ust-uda
# Processing Record 27 of Set 11 | lugovskiy
# City not found. Skipping...
# Processing Record 28 of Set 11 | lorengau
# Processing Record 29 of Set 11 | ornskoldsvik
# Processing Record 30 of Set 11 | port shepstone
# Processing Record 31 of Set 11 | tunxi
# City not found. Skipping...
# Processing Record 32 of Set 11 | tamandare
# Processing Record 33 of Set 11 | namatanai
# Processing Record 34 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 35 of Set 11 | camana
# Processing Record 36 of Set 11 | tautira
# Processing Record 37 of Set 11 | moskovskiy
# Processing Record 38 of Set 11 | riohacha
# Processing Record 39 of Set 11 | alice springs
# Processing Record 40 of Set 11 | la maddalena
# Processing Record 41 of Set 11 | los llanos de aridane
# Processing Record 42 of Set 11 | hampton
# Processing Record 43 of Set 11 | acari
# Processing Record 44 of Set 11 | puerto escondido
# Processing Record 45 of Set 11 | padang
# Processing Record 46 of Set 11 | nichinan
# Processing Record 47 of Set 11 | raga
# Processing Record 48 of Set 11 | sobolevo
# Processing Record 49 of Set 11 | mlonggo
# Processing Record 50 of Set 11 | zhengjiatun
# Processing Record 1 of Set 12 | pacific grove
# Processing Record 2 of Set 12 | almeirim
# Processing Record 3 of Set 12 | grafton
# Processing Record 4 of Set 12 | biak
# Processing Record 5 of Set 12 | hulst
# Processing Record 6 of Set 12 | kaeo
# Processing Record 7 of Set 12 | hamilton
# Processing Record 8 of Set 12 | tumen
# Processing Record 9 of Set 12 | klaksvik
# Processing Record 10 of Set 12 | sitka
# Processing Record 11 of Set 12 | buraydah
# Processing Record 12 of Set 12 | eugene
# Processing Record 13 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 12 | andros town
# Processing Record 15 of Set 12 | kurumkan
# Processing Record 16 of Set 12 | talnakh
# Processing Record 17 of Set 12 | flin flon
# Processing Record 18 of Set 12 | lashio
# Processing Record 19 of Set 12 | mabaruma
# Processing Record 20 of Set 12 | zeya
# Processing Record 21 of Set 12 | hoquiam
# Processing Record 22 of Set 12 | ust-maya
# Processing Record 23 of Set 12 | nagato
# Processing Record 24 of Set 12 | alugan
# Processing Record 25 of Set 12 | kendari
# Processing Record 26 of Set 12 | copperas cove
# Processing Record 27 of Set 12 | devaprayag
# Processing Record 28 of Set 12 | bongandanga
# Processing Record 29 of Set 12 | cariamanga
# Processing Record 30 of Set 12 | platteville
# Processing Record 31 of Set 12 | jingdezhen
# Processing Record 32 of Set 12 | karratha
# Processing Record 33 of Set 12 | ndago
# Processing Record 34 of Set 12 | noumea
# Processing Record 35 of Set 12 | paragominas
# Processing Record 36 of Set 12 | baykit
# Processing Record 37 of Set 12 | durango
# Processing Record 38 of Set 12 | catuday
# Processing Record 39 of Set 12 | tres picos
# Processing Record 40 of Set 12 | hobyo
# Processing Record 41 of Set 12 | vanimo
# Processing Record 42 of Set 12 | cape elizabeth
# City not found. Skipping...
# Processing Record 43 of Set 12 | belomorsk
# Processing Record 44 of Set 12 | madaba
# Processing Record 45 of Set 12 | srednekolymsk
# Processing Record 46 of Set 12 | jiaozuo
# Processing Record 47 of Set 12 | sooke
# Processing Record 48 of Set 12 | miraflores
# Processing Record 49 of Set 12 | nalut
# Processing Record 50 of Set 12 | kharp
# Processing Record 1 of Set 13 | vyazovaya
# Processing Record 2 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 3 of Set 13 | taksimo
# Processing Record 4 of Set 13 | camacha
# Processing Record 5 of Set 13 | canton
# Processing Record 6 of Set 13 | tabialan
# City not found. Skipping...
# Processing Record 7 of Set 13 | kuruman
# Processing Record 8 of Set 13 | ikom
# Processing Record 9 of Set 13 | ivanteyevka
# Processing Record 10 of Set 13 | krasnyy oktyabr
# Processing Record 11 of Set 13 | tokmak
# Processing Record 12 of Set 13 | mogadishu
# Processing Record 13 of Set 13 | paciran
# Processing Record 14 of Set 13 | ullapool
# Processing Record 15 of Set 13 | zhangye
# Processing Record 16 of Set 13 | jiuquan
# Processing Record 17 of Set 13 | iquitos
# Processing Record 18 of Set 13 | marovoay
# Processing Record 19 of Set 13 | barra do garcas
# Processing Record 20 of Set 13 | penzance
# Processing Record 21 of Set 13 | carutapera
# Processing Record 22 of Set 13 | arlit
# Processing Record 23 of Set 13 | jinchang
# Processing Record 24 of Set 13 | pangnirtung
# Processing Record 25 of Set 13 | severodvinsk
# Processing Record 26 of Set 13 | aksu
# Processing Record 27 of Set 13 | milkovo
# Processing Record 28 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 13 | buala
# Processing Record 30 of Set 13 | tayu
# Processing Record 31 of Set 13 | tutoia
# Processing Record 32 of Set 13 | tabou
# Processing Record 33 of Set 13 | adilabad
# Processing Record 34 of Set 13 | aquidauana
# Processing Record 35 of Set 13 | great yarmouth
# Processing Record 36 of Set 13 | mapiri
# Processing Record 37 of Set 13 | kutum
# Processing Record 38 of Set 13 | gigmoto
# Processing Record 39 of Set 13 | kirkwall
# Processing Record 40 of Set 13 | itoman
# Processing Record 41 of Set 13 | sola
# Processing Record 42 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 13 | iskitim
# Processing Record 44 of Set 13 | mata
# Processing Record 45 of Set 13 | calapi
# Processing Record 46 of Set 13 | prainha
# Processing Record 47 of Set 13 | caucaia
# Processing Record 48 of Set 13 | play cu
# City not found. Skipping...
# Processing Record 49 of Set 13 | tadine
# Processing Record 50 of Set 13 | kirovskiy
# Processing Record 1 of Set 14 | batemans bay
# Processing Record 2 of Set 14 | banapur
# Processing Record 3 of Set 14 | buin
# Processing Record 4 of Set 14 | ulaangom
# Processing Record 5 of Set 14 | bonavista
# Processing Record 6 of Set 14 | payson
# Processing Record 7 of Set 14 | mount gambier
# Processing Record 8 of Set 14 | new bedford
# Processing Record 9 of Set 14 | sao paulo de olivenca
# Processing Record 10 of Set 14 | hovd
# Processing Record 11 of Set 14 | grootfontein
# Processing Record 12 of Set 14 | atasu
# Processing Record 13 of Set 14 | san jeronimo
# Processing Record 14 of Set 14 | cercal
# Processing Record 15 of Set 14 | jalu
# Processing Record 16 of Set 14 | presidencia roque saenz pena
# Processing Record 17 of Set 14 | gejiu
# Processing Record 18 of Set 14 | gillette
# Processing Record 19 of Set 14 | kawalu
# Processing Record 20 of Set 14 | braniewo
# Processing Record 21 of Set 14 | mandalgovi
# Processing Record 22 of Set 14 | bayshore gardens
# Processing Record 23 of Set 14 | el alto
# Processing Record 24 of Set 14 | scottsboro
# Processing Record 25 of Set 14 | fort nelson
# Processing Record 26 of Set 14 | hay river
# Processing Record 27 of Set 14 | teya
# Processing Record 28 of Set 14 | skagastrond
# City not found. Skipping...
# Processing Record 29 of Set 14 | sorland
# Processing Record 30 of Set 14 | victor harbor
# Processing Record 31 of Set 14 | erenhot
# Processing Record 32 of Set 14 | bulgan
# Processing Record 33 of Set 14 | myaundzha
# Processing Record 34 of Set 14 | tigil
# Processing Record 35 of Set 14 | acapulco
# Processing Record 36 of Set 14 | verkhoyansk
# Processing Record 37 of Set 14 | kemin
# Processing Record 38 of Set 14 | beloha
# Processing Record 39 of Set 14 | menongue
# Processing Record 40 of Set 14 | nelson bay
# Processing Record 41 of Set 14 | maceio
# Processing Record 42 of Set 14 | qaqortoq
# Processing Record 43 of Set 14 | la ronge
# Processing Record 44 of Set 14 | gaoua
# Processing Record 45 of Set 14 | quatre cocos
# Processing Record 46 of Set 14 | abancay
# Processing Record 47 of Set 14 | fare
# Processing Record 48 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 49 of Set 14 | petropavl
# Processing Record 50 of Set 14 | mocuba
# Processing Record 1 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 2 of Set 15 | richards bay
# Processing Record 3 of Set 15 | dukat
# Processing Record 4 of Set 15 | nilopolis
# Processing Record 5 of Set 15 | puerto el triunfo
# Processing Record 6 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 15 | vilyuysk
# Processing Record 8 of Set 15 | stokmarknes
# Processing Record 9 of Set 15 | khasan
# Processing Record 10 of Set 15 | navrongo
# Processing Record 11 of Set 15 | bilma
# Processing Record 12 of Set 15 | hire
# City not found. Skipping...
# Processing Record 13 of Set 15 | valle de allende
# Processing Record 14 of Set 15 | van buren
# Processing Record 15 of Set 15 | caravelas
# Processing Record 16 of Set 15 | seoul
# Processing Record 17 of Set 15 | zhigansk
# Processing Record 18 of Set 15 | tanout
# Processing Record 19 of Set 15 | shelburne
# Processing Record 20 of Set 15 | morfelden-walldorf
# Processing Record 21 of Set 15 | tocopilla
# Processing Record 22 of Set 15 | nyurba
# Processing Record 23 of Set 15 | wexford
# Processing Record 24 of Set 15 | nyagan
# Processing Record 25 of Set 15 | shasta lake
# Processing Record 26 of Set 15 | san miguel
# Processing Record 27 of Set 15 | champasak
# Processing Record 28 of Set 15 | curvelo
# Processing Record 29 of Set 15 | asmara
# Processing Record 30 of Set 15 | kamenka
# Processing Record 31 of Set 15 | luanda
# Processing Record 32 of Set 15 | kununurra
# Processing Record 33 of Set 15 | brooks
# Processing Record 34 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 15 | pinjaur
# Processing Record 36 of Set 15 | owase
# Processing Record 37 of Set 15 | marsabit
# Processing Record 38 of Set 15 | mildura
# Processing Record 39 of Set 15 | riyadh
# Processing Record 40 of Set 15 | namibe
# Processing Record 41 of Set 15 | nizhniy odes
# Processing Record 42 of Set 15 | laguna
# Processing Record 43 of Set 15 | simpang
# Processing Record 44 of Set 15 | lufilufi
# Processing Record 45 of Set 15 | steubenville
# Processing Record 46 of Set 15 | uba
# Processing Record 47 of Set 15 | darhan
# Processing Record 48 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 15 | haines junction
# Processing Record 50 of Set 15 | ziway
# Processing Record 1 of Set 16 | bairiki
# Processing Record 2 of Set 16 | boysun
# Processing Record 3 of Set 16 | reftinskiy
# Processing Record 4 of Set 16 | candawaga
# City not found. Skipping...
# Processing Record 5 of Set 16 | carauari
# Processing Record 6 of Set 16 | kokopo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0         Macia -25.0269   33.0989           clear sky     69.37        57
# 1       Bubaque  11.2833  -15.8333       moderate rain     78.94        84
# 2       Mataura -46.1927  168.8643     overcast clouds     47.48        99
# 3     Upernavik  72.7868  -56.1549     overcast clouds     41.81        80
# 4     Jamestown  42.0970  -79.2353           clear sky     68.18        71
# 5      Khatanga  71.9667  102.5000           clear sky     71.96        36
# 6    Chokurdakh  70.6333  147.9167     overcast clouds     37.63        83
# 7     Hithadhoo  -0.6000   73.0833     overcast clouds     81.70        73
# 8      Hermanus -34.4187   19.2345     overcast clouds     67.89        79
# 9  Punta Arenas -53.1500  -70.9167     overcast clouds     41.11        65
#
#    Cloudiness  Wind Speed Country                 Date
# 0           0        9.01      MZ  2021-07-31 15:01:01
# 1         100       18.86      GW  2021-07-31 15:01:02
# 2         100        1.01      NZ  2021-07-31 15:01:02
# 3         100        9.95      GL  2021-07-31 15:01:03
# 4           0        4.00      US  2021-07-31 15:00:21
# 5           8       12.35      RU  2021-07-31 15:01:04
# 6         100       20.09      RU  2021-07-31 15:01:04
# 7          86        4.74      MV  2021-07-31 15:01:05
# 8         100        2.10      ZA  2021-07-31 15:01:05
# 9         100       18.01      CL  2021-07-31 15:01:05

# %%
#Reorder the columns
new_column_order = ["City", "Country","Lat","Lng","Max Temp", "Humidity","Cloudiness","Wind Speed", "Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Macia      MZ -25.0269   33.0989     69.37        57           0
# 1    Bubaque      GW  11.2833  -15.8333     78.94        84         100
# 2    Mataura      NZ -46.1927  168.8643     47.48        99         100
# 3  Upernavik      GL  72.7868  -56.1549     41.81        80         100
# 4  Jamestown      US  42.0970  -79.2353     68.18        71           0
#
#    Wind Speed Current Description
# 0        9.01           clear sky
# 1       18.86       moderate rain
# 2        1.01     overcast clouds
# 3        9.95     overcast clouds
# 4        4.00           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
