# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import csv

# %%
# Create a set of random latitude and longitude combinations.
## Create a set of 2000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
 # Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 783

# %%
# Import the requests library.
import requests

# Import the API key.
from config_1 import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e2c0addb2379ad604f19c90b9428be2

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        weather_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": weather_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 1 | geresk
# City not found. Skipping...
# Processing Record 3 of Set 1 | bambous virieux
# Processing Record 4 of Set 1 | khatanga
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | ullapool
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | bereda
# Processing Record 9 of Set 1 | dzhebariki-khaya
# Processing Record 10 of Set 1 | americus
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | nizwa
# Processing Record 16 of Set 1 | deputatskiy
# Processing Record 17 of Set 1 | victoria
# Processing Record 18 of Set 1 | ati
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | sao filipe
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | katsuura
# Processing Record 23 of Set 1 | sur
# Processing Record 24 of Set 1 | talnakh
# Processing Record 25 of Set 1 | ruidoso
# Processing Record 26 of Set 1 | upernavik
# Processing Record 27 of Set 1 | tasiilaq
# Processing Record 28 of Set 1 | asyut
# Processing Record 29 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 1 | champerico
# Processing Record 31 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 1 | kadykchan
# City not found. Skipping...
# Processing Record 33 of Set 1 | kruisfontein
# Processing Record 34 of Set 1 | kavaratti
# Processing Record 35 of Set 1 | fairbanks
# Processing Record 36 of Set 1 | te anau
# Processing Record 37 of Set 1 | vestmannaeyjar
# Processing Record 38 of Set 1 | buraydah
# Processing Record 39 of Set 1 | pochutla
# Processing Record 40 of Set 1 | ambodifototra
# City not found. Skipping...
# Processing Record 41 of Set 1 | lagoa
# Processing Record 42 of Set 1 | ribeira grande
# Processing Record 43 of Set 1 | clyde river
# Processing Record 44 of Set 1 | morondava
# Processing Record 45 of Set 1 | mangaratiba
# Processing Record 46 of Set 1 | severodvinsk
# Processing Record 47 of Set 1 | cururupu
# Processing Record 48 of Set 1 | dingle
# Processing Record 49 of Set 1 | rikitea
# Processing Record 50 of Set 1 | jamestown
# Processing Record 1 of Set 2 | riyadh
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | kapaa
# Processing Record 4 of Set 2 | nikolskoye
# Processing Record 5 of Set 2 | saldanha
# Processing Record 6 of Set 2 | bathurst
# Processing Record 7 of Set 2 | azare
# Processing Record 8 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 2 | sao felix do xingu
# Processing Record 10 of Set 2 | dikson
# Processing Record 11 of Set 2 | quchan
# Processing Record 12 of Set 2 | severo-kurilsk
# Processing Record 13 of Set 2 | bagotville
# Processing Record 14 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 2 | maldonado
# Processing Record 16 of Set 2 | carnarvon
# Processing Record 17 of Set 2 | albany
# Processing Record 18 of Set 2 | faanui
# Processing Record 19 of Set 2 | provideniya
# Processing Record 20 of Set 2 | taunggyi
# Processing Record 21 of Set 2 | celestun
# Processing Record 22 of Set 2 | bathsheba
# Processing Record 23 of Set 2 | lebu
# Processing Record 24 of Set 2 | amuntai
# Processing Record 25 of Set 2 | grenaa
# Processing Record 26 of Set 2 | pisco
# Processing Record 27 of Set 2 | port augusta
# Processing Record 28 of Set 2 | dolores
# Processing Record 29 of Set 2 | oussouye
# Processing Record 30 of Set 2 | tiksi
# Processing Record 31 of Set 2 | campoverde
# Processing Record 32 of Set 2 | beringovskiy
# Processing Record 33 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 34 of Set 2 | cape town
# Processing Record 35 of Set 2 | ridgecrest
# Processing Record 36 of Set 2 | east london
# Processing Record 37 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 2 | xining
# Processing Record 39 of Set 2 | piney green
# Processing Record 40 of Set 2 | cocorit
# Processing Record 41 of Set 2 | geraldton
# Processing Record 42 of Set 2 | vaini
# Processing Record 43 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 2 | poroschia
# Processing Record 45 of Set 2 | ituni
# City not found. Skipping...
# Processing Record 46 of Set 2 | inhambane
# Processing Record 47 of Set 2 | stykkisholmur
# Processing Record 48 of Set 2 | belmonte
# Processing Record 49 of Set 2 | weihe
# Processing Record 50 of Set 2 | bouza
# Processing Record 1 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 3 | bluff
# Processing Record 3 of Set 3 | sola
# Processing Record 4 of Set 3 | atagay
# Processing Record 5 of Set 3 | chuy
# Processing Record 6 of Set 3 | azimur
# City not found. Skipping...
# Processing Record 7 of Set 3 | laem sing
# Processing Record 8 of Set 3 | leningradskiy
# Processing Record 9 of Set 3 | iqaluit
# Processing Record 10 of Set 3 | mahebourg
# Processing Record 11 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 3 | mananjary
# Processing Record 13 of Set 3 | mar del plata
# Processing Record 14 of Set 3 | hobart
# Processing Record 15 of Set 3 | perleberg
# Processing Record 16 of Set 3 | avarua
# Processing Record 17 of Set 3 | srivardhan
# Processing Record 18 of Set 3 | demerval lobao
# Processing Record 19 of Set 3 | hami
# Processing Record 20 of Set 3 | pomichna
# Processing Record 21 of Set 3 | kodiak
# Processing Record 22 of Set 3 | new norfolk
# Processing Record 23 of Set 3 | saint-pierre
# Processing Record 24 of Set 3 | oakdale
# Processing Record 25 of Set 3 | carlisle
# Processing Record 26 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 3 | juneau
# Processing Record 28 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 3 | cosala
# Processing Record 30 of Set 3 | airai
# Processing Record 31 of Set 3 | ancud
# Processing Record 32 of Set 3 | quatre cocos
# Processing Record 33 of Set 3 | alofi
# Processing Record 34 of Set 3 | yar-sale
# Processing Record 35 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 36 of Set 3 | kahului
# Processing Record 37 of Set 3 | ponta do sol
# Processing Record 38 of Set 3 | helong
# Processing Record 39 of Set 3 | hilo
# Processing Record 40 of Set 3 | souillac
# Processing Record 41 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 42 of Set 3 | hermanus
# Processing Record 43 of Set 3 | tahoua
# Processing Record 44 of Set 3 | autun
# Processing Record 45 of Set 3 | margate
# Processing Record 46 of Set 3 | belaya gora
# Processing Record 47 of Set 3 | nova lima
# Processing Record 48 of Set 3 | cabo san lucas
# Processing Record 49 of Set 3 | mataura
# Processing Record 50 of Set 3 | streator
# Processing Record 1 of Set 4 | porto novo
# Processing Record 2 of Set 4 | cherskiy
# Processing Record 3 of Set 4 | poum
# Processing Record 4 of Set 4 | avera
# Processing Record 5 of Set 4 | abha
# Processing Record 6 of Set 4 | makakilo city
# Processing Record 7 of Set 4 | ciudad guayana
# Processing Record 8 of Set 4 | craig
# Processing Record 9 of Set 4 | paamiut
# Processing Record 10 of Set 4 | kaitangata
# Processing Record 11 of Set 4 | nelson bay
# Processing Record 12 of Set 4 | burnie
# Processing Record 13 of Set 4 | kristinehamn
# Processing Record 14 of Set 4 | zlatoustovsk
# City not found. Skipping...
# Processing Record 15 of Set 4 | kalmunai
# Processing Record 16 of Set 4 | harer
# Processing Record 17 of Set 4 | khalimbekaul
# Processing Record 18 of Set 4 | bengkulu
# Processing Record 19 of Set 4 | mildura
# Processing Record 20 of Set 4 | sao joao da barra
# Processing Record 21 of Set 4 | harnosand
# Processing Record 22 of Set 4 | nuuk
# Processing Record 23 of Set 4 | dalvik
# Processing Record 24 of Set 4 | sistranda
# Processing Record 25 of Set 4 | atar
# Processing Record 26 of Set 4 | thompson
# Processing Record 27 of Set 4 | namatanai
# Processing Record 28 of Set 4 | saint george
# Processing Record 29 of Set 4 | otse
# Processing Record 30 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 31 of Set 4 | olga
# Processing Record 32 of Set 4 | road town
# Processing Record 33 of Set 4 | norman wells
# Processing Record 34 of Set 4 | aklavik
# Processing Record 35 of Set 4 | itarema
# Processing Record 36 of Set 4 | ponta delgada
# Processing Record 37 of Set 4 | port blair
# Processing Record 38 of Set 4 | vila
# Processing Record 39 of Set 4 | termiz
# Processing Record 40 of Set 4 | los llanos de aridane
# Processing Record 41 of Set 4 | saskylakh
# Processing Record 42 of Set 4 | vardo
# Processing Record 43 of Set 4 | novouzensk
# Processing Record 44 of Set 4 | touros
# Processing Record 45 of Set 4 | hasaki
# Processing Record 46 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 47 of Set 4 | hastings
# Processing Record 48 of Set 4 | adrar
# Processing Record 49 of Set 4 | henties bay
# Processing Record 50 of Set 4 | mezhova
# Processing Record 1 of Set 5 | lebedinyy
# Processing Record 2 of Set 5 | castro
# Processing Record 3 of Set 5 | torbay
# Processing Record 4 of Set 5 | lavrentiya
# Processing Record 5 of Set 5 | bairiki
# Processing Record 6 of Set 5 | qaanaaq
# Processing Record 7 of Set 5 | ziro
# Processing Record 8 of Set 5 | megion
# Processing Record 9 of Set 5 | ballina
# Processing Record 10 of Set 5 | vanimo
# Processing Record 11 of Set 5 | tweed
# Processing Record 12 of Set 5 | kudahuvadhoo
# Processing Record 13 of Set 5 | erzin
# Processing Record 14 of Set 5 | bilibino
# Processing Record 15 of Set 5 | rock sound
# Processing Record 16 of Set 5 | blacksburg
# Processing Record 17 of Set 5 | nouakchott
# Processing Record 18 of Set 5 | georgetown
# Processing Record 19 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 20 of Set 5 | vondrozo
# Processing Record 21 of Set 5 | malakal
# Processing Record 22 of Set 5 | russell
# Processing Record 23 of Set 5 | nanortalik
# Processing Record 24 of Set 5 | araguari
# Processing Record 25 of Set 5 | hithadhoo
# Processing Record 26 of Set 5 | albanel
# Processing Record 27 of Set 5 | dryden
# Processing Record 28 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 5 | port elizabeth
# Processing Record 30 of Set 5 | longyearbyen
# Processing Record 31 of Set 5 | ostrovnoy
# Processing Record 32 of Set 5 | north platte
# Processing Record 33 of Set 5 | aykhal
# Processing Record 34 of Set 5 | broken hill
# Processing Record 35 of Set 5 | saint-philippe
# Processing Record 36 of Set 5 | misratah
# Processing Record 37 of Set 5 | afrikanda
# Processing Record 38 of Set 5 | san patricio
# Processing Record 39 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 5 | monrovia
# Processing Record 41 of Set 5 | balakhta
# Processing Record 42 of Set 5 | evensk
# Processing Record 43 of Set 5 | japura
# Processing Record 44 of Set 5 | northam
# Processing Record 45 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 5 | mount gambier
# Processing Record 47 of Set 5 | carmo do paranaiba
# Processing Record 48 of Set 5 | srednekolymsk
# Processing Record 49 of Set 5 | arlit
# Processing Record 50 of Set 5 | brazzaville
# Processing Record 1 of Set 6 | belonia
# Processing Record 2 of Set 6 | masterton
# Processing Record 3 of Set 6 | alexandria
# Processing Record 4 of Set 6 | samana
# Processing Record 5 of Set 6 | port-cartier
# Processing Record 6 of Set 6 | barrow
# Processing Record 7 of Set 6 | harper
# Processing Record 8 of Set 6 | berdigestyakh
# Processing Record 9 of Set 6 | constitucion
# Processing Record 10 of Set 6 | port alfred
# Processing Record 11 of Set 6 | okmulgee
# Processing Record 12 of Set 6 | hong gai
# Processing Record 13 of Set 6 | mezen
# Processing Record 14 of Set 6 | mogadishu
# Processing Record 15 of Set 6 | grindavik
# Processing Record 16 of Set 6 | hovd
# Processing Record 17 of Set 6 | umm lajj
# Processing Record 18 of Set 6 | bintulu
# Processing Record 19 of Set 6 | mount isa
# Processing Record 20 of Set 6 | callaway
# Processing Record 21 of Set 6 | san cristobal
# Processing Record 22 of Set 6 | gamboma
# Processing Record 23 of Set 6 | ulaanbaatar
# Processing Record 24 of Set 6 | karratha
# Processing Record 25 of Set 6 | vostok
# Processing Record 26 of Set 6 | tarko-sale
# Processing Record 27 of Set 6 | camacha
# Processing Record 28 of Set 6 | magadan
# Processing Record 29 of Set 6 | jamay
# Processing Record 30 of Set 6 | thinadhoo
# Processing Record 31 of Set 6 | najran
# Processing Record 32 of Set 6 | trinidad
# Processing Record 33 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 34 of Set 6 | mount darwin
# Processing Record 35 of Set 6 | pangnirtung
# Processing Record 36 of Set 6 | luderitz
# Processing Record 37 of Set 6 | coihaique
# Processing Record 38 of Set 6 | williston
# Processing Record 39 of Set 6 | bredasdorp
# Processing Record 40 of Set 6 | bernalillo
# Processing Record 41 of Set 6 | esperance
# Processing Record 42 of Set 6 | arraial do cabo
# Processing Record 43 of Set 6 | point fortin
# Processing Record 44 of Set 6 | nioro
# Processing Record 45 of Set 6 | iraquara
# Processing Record 46 of Set 6 | portland
# Processing Record 47 of Set 6 | shunyi
# Processing Record 48 of Set 6 | dumas
# Processing Record 49 of Set 6 | praia da vitoria
# Processing Record 50 of Set 6 | mopipi
# Processing Record 1 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 7 | bajah
# Processing Record 3 of Set 7 | sehithwa
# Processing Record 4 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 7 | atambua
# Processing Record 6 of Set 7 | bonavista
# Processing Record 7 of Set 7 | lasa
# Processing Record 8 of Set 7 | mabaruma
# Processing Record 9 of Set 7 | denpasar
# Processing Record 10 of Set 7 | qasigiannguit
# Processing Record 11 of Set 7 | aksu
# Processing Record 12 of Set 7 | nicoya
# Processing Record 13 of Set 7 | mulege
# Processing Record 14 of Set 7 | orikum
# Processing Record 15 of Set 7 | ahipara
# Processing Record 16 of Set 7 | tiarei
# Processing Record 17 of Set 7 | piopio
# Processing Record 18 of Set 7 | kokoda
# Processing Record 19 of Set 7 | damietta
# Processing Record 20 of Set 7 | naze
# Processing Record 21 of Set 7 | villa carlos paz
# Processing Record 22 of Set 7 | medvedovskaya
# Processing Record 23 of Set 7 | malaryta
# Processing Record 24 of Set 7 | verkhozim
# Processing Record 25 of Set 7 | chernyshevskiy
# Processing Record 26 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 7 | tual
# Processing Record 28 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 29 of Set 7 | canete
# Processing Record 30 of Set 7 | serov
# Processing Record 31 of Set 7 | mayumba
# Processing Record 32 of Set 7 | karla
# Processing Record 33 of Set 7 | vila franca do campo
# Processing Record 34 of Set 7 | gomel
# Processing Record 35 of Set 7 | hukuntsi
# Processing Record 36 of Set 7 | aljezur
# Processing Record 37 of Set 7 | husavik
# Processing Record 38 of Set 7 | oum hadjer
# Processing Record 39 of Set 7 | saint-augustin
# Processing Record 40 of Set 7 | vaitape
# Processing Record 41 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 7 | zabol
# Processing Record 43 of Set 7 | tifton
# Processing Record 44 of Set 7 | pevek
# Processing Record 45 of Set 7 | takoradi
# Processing Record 46 of Set 7 | peniche
# Processing Record 47 of Set 7 | umm kaddadah
# Processing Record 48 of Set 7 | faya
# Processing Record 49 of Set 7 | surgut
# Processing Record 50 of Set 7 | tabarqah
# City not found. Skipping...
# Processing Record 1 of Set 8 | mamakan
# Processing Record 2 of Set 8 | pecos
# Processing Record 3 of Set 8 | george town
# Processing Record 4 of Set 8 | yumen
# Processing Record 5 of Set 8 | richards bay
# Processing Record 6 of Set 8 | teahupoo
# Processing Record 7 of Set 8 | hofn
# Processing Record 8 of Set 8 | leshukonskoye
# Processing Record 9 of Set 8 | tungkang
# City not found. Skipping...
# Processing Record 10 of Set 8 | tucupita
# Processing Record 11 of Set 8 | gaziantep
# Processing Record 12 of Set 8 | stornoway
# Processing Record 13 of Set 8 | korla
# Processing Record 14 of Set 8 | kieta
# Processing Record 15 of Set 8 | doha
# Processing Record 16 of Set 8 | nantai
# Processing Record 17 of Set 8 | patan
# Processing Record 18 of Set 8 | fortuna
# Processing Record 19 of Set 8 | chanika
# Processing Record 20 of Set 8 | bilma
# Processing Record 21 of Set 8 | san quintin
# Processing Record 22 of Set 8 | cartagena
# Processing Record 23 of Set 8 | manturovo
# Processing Record 24 of Set 8 | mehamn
# Processing Record 25 of Set 8 | olinda
# Processing Record 26 of Set 8 | inuvik
# Processing Record 27 of Set 8 | cap malheureux
# Processing Record 28 of Set 8 | san carlos de bariloche
# Processing Record 29 of Set 8 | marawi
# Processing Record 30 of Set 8 | turayf
# Processing Record 31 of Set 8 | codrington
# Processing Record 32 of Set 8 | bahia blanca
# Processing Record 33 of Set 8 | stoyba
# City not found. Skipping...
# Processing Record 34 of Set 8 | yondo
# Processing Record 35 of Set 8 | pitkyaranta
# Processing Record 36 of Set 8 | verkhnevilyuysk
# Processing Record 37 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 38 of Set 8 | dajabon
# Processing Record 39 of Set 8 | jiroft
# City not found. Skipping...
# Processing Record 40 of Set 8 | port hedland
# Processing Record 41 of Set 8 | mouzakion
# City not found. Skipping...
# Processing Record 42 of Set 8 | grozesti
# Processing Record 43 of Set 8 | svolvaer
# Processing Record 44 of Set 8 | sobolevo
# Processing Record 45 of Set 8 | necochea
# Processing Record 46 of Set 8 | teacapan
# Processing Record 47 of Set 8 | port-de-paix
# City not found. Skipping...
# Processing Record 48 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 8 | quelimane
# Processing Record 50 of Set 8 | fougamou
# Processing Record 1 of Set 9 | cabedelo
# Processing Record 2 of Set 9 | santa fe
# Processing Record 3 of Set 9 | rincon
# Processing Record 4 of Set 9 | college
# Processing Record 5 of Set 9 | klaksvik
# Processing Record 6 of Set 9 | bethel
# Processing Record 7 of Set 9 | dongying
# Processing Record 8 of Set 9 | khelyulya
# Processing Record 9 of Set 9 | hobyo
# Processing Record 10 of Set 9 | andenes
# Processing Record 11 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 12 of Set 9 | matagami
# Processing Record 13 of Set 9 | coquimbo
# Processing Record 14 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 15 of Set 9 | burgeo
# Processing Record 16 of Set 9 | tres palos
# Processing Record 17 of Set 9 | bamako
# Processing Record 18 of Set 9 | den helder
# Processing Record 19 of Set 9 | soni
# Processing Record 20 of Set 9 | arkhangelos
# City not found. Skipping...
# Processing Record 21 of Set 9 | kenai
# Processing Record 22 of Set 9 | severobaykalsk
# Processing Record 23 of Set 9 | bonthe
# Processing Record 24 of Set 9 | morro bay
# Processing Record 25 of Set 9 | gravelbourg
# Processing Record 26 of Set 9 | wanlaweyn
# Processing Record 27 of Set 9 | lewisporte
# Processing Record 28 of Set 9 | hambantota
# Processing Record 29 of Set 9 | lukovetskiy
# Processing Record 30 of Set 9 | price
# Processing Record 31 of Set 9 | la palma
# Processing Record 32 of Set 9 | sungai besar
# Processing Record 33 of Set 9 | ouahigouya
# Processing Record 34 of Set 9 | guerrero negro
# Processing Record 35 of Set 9 | kavieng
# Processing Record 36 of Set 9 | lulea
# Processing Record 37 of Set 9 | bambanglipuro
# Processing Record 38 of Set 9 | merauke
# Processing Record 39 of Set 9 | drovyanaya
# Processing Record 40 of Set 9 | urumqi
# Processing Record 41 of Set 9 | comodoro rivadavia
# Processing Record 42 of Set 9 | osypenko
# Processing Record 43 of Set 9 | maltahohe
# Processing Record 44 of Set 9 | liverpool
# Processing Record 45 of Set 9 | rapu-rapu
# Processing Record 46 of Set 9 | meulaboh
# Processing Record 47 of Set 9 | nzega
# Processing Record 48 of Set 9 | boa vista
# Processing Record 49 of Set 9 | karamay
# City not found. Skipping...
# Processing Record 50 of Set 9 | tripoli
# Processing Record 1 of Set 10 | krasnoselkup
# Processing Record 2 of Set 10 | cabra
# Processing Record 3 of Set 10 | pundaguitan
# Processing Record 4 of Set 10 | minab
# Processing Record 5 of Set 10 | zhanaozen
# Processing Record 6 of Set 10 | palmer
# Processing Record 7 of Set 10 | catuday
# Processing Record 8 of Set 10 | sinnamary
# Processing Record 9 of Set 10 | marzuq
# Processing Record 10 of Set 10 | mitsamiouli
# Processing Record 11 of Set 10 | kamen-rybolov
# Processing Record 12 of Set 10 | kununurra
# Processing Record 13 of Set 10 | missoula
# Processing Record 14 of Set 10 | sambava
# Processing Record 15 of Set 10 | high level
# Processing Record 16 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 17 of Set 10 | christchurch
# Processing Record 18 of Set 10 | carballo
# Processing Record 19 of Set 10 | kushiro
# Processing Record 20 of Set 10 | baiyin
# Processing Record 21 of Set 10 | saint anthony
# Processing Record 22 of Set 10 | bac lieu
# Processing Record 23 of Set 10 | baherden
# Processing Record 24 of Set 10 | yamaranguila
# Processing Record 25 of Set 10 | henderson
# Processing Record 26 of Set 10 | lagos
# Processing Record 27 of Set 10 | kloulklubed
# Processing Record 28 of Set 10 | nynashamn
# Processing Record 29 of Set 10 | svetlogorsk
# Processing Record 30 of Set 10 | komsomolskiy
# Processing Record 31 of Set 10 | pandan
# Processing Record 32 of Set 10 | bar harbor
# Processing Record 33 of Set 10 | tigil
# Processing Record 34 of Set 10 | douglas
# Processing Record 35 of Set 10 | blagoyevo
# Processing Record 36 of Set 10 | kongoussi
# Processing Record 37 of Set 10 | santa ines
# Processing Record 38 of Set 10 | pucallpa
# Processing Record 39 of Set 10 | innisfail
# Processing Record 40 of Set 10 | farafangana
# Processing Record 41 of Set 10 | garoua boulai
# Processing Record 42 of Set 10 | alyangula
# Processing Record 43 of Set 10 | jodhpur
# Processing Record 44 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 45 of Set 10 | maraba
# Processing Record 46 of Set 10 | cidreira
# Processing Record 47 of Set 10 | gravdal
# Processing Record 48 of Set 10 | ayan
# Processing Record 49 of Set 10 | rybinsk
# Processing Record 50 of Set 10 | tocopilla
# Processing Record 1 of Set 11 | poya
# Processing Record 2 of Set 11 | kungurtug
# Processing Record 3 of Set 11 | prince rupert
# Processing Record 4 of Set 11 | rawson
# Processing Record 5 of Set 11 | muroto
# Processing Record 6 of Set 11 | basdiot
# Processing Record 7 of Set 11 | pechora
# Processing Record 8 of Set 11 | tirumullaivasal
# Processing Record 9 of Set 11 | borbon
# Processing Record 10 of Set 11 | chiang klang
# Processing Record 11 of Set 11 | mandiana
# Processing Record 12 of Set 11 | maniitsoq
# Processing Record 13 of Set 11 | waycross
# Processing Record 14 of Set 11 | zolotinka
# City not found. Skipping...
# Processing Record 15 of Set 11 | praya
# Processing Record 16 of Set 11 | boromo
# Processing Record 17 of Set 11 | niksar
# Processing Record 18 of Set 11 | sancti spiritus
# Processing Record 19 of Set 11 | lazaro cardenas
# Processing Record 20 of Set 11 | blackwater
# Processing Record 21 of Set 11 | nara
# Processing Record 22 of Set 11 | ahumada
# City not found. Skipping...
# Processing Record 23 of Set 11 | bullhead city
# Processing Record 24 of Set 11 | tumpat
# Processing Record 25 of Set 11 | neuquen
# Processing Record 26 of Set 11 | laguna
# Processing Record 27 of Set 11 | berlevag
# Processing Record 28 of Set 11 | beloha
# Processing Record 29 of Set 11 | matara
# Processing Record 30 of Set 11 | batagay
# Processing Record 31 of Set 11 | seoul
# Processing Record 32 of Set 11 | labuhan
# Processing Record 33 of Set 11 | ermelo
# Processing Record 34 of Set 11 | honningsvag
# Processing Record 35 of Set 11 | santiago del estero
# Processing Record 36 of Set 11 | graham
# Processing Record 37 of Set 11 | foki
# Processing Record 38 of Set 11 | viedma
# Processing Record 39 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 40 of Set 11 | maceio
# Processing Record 41 of Set 11 | jinxiang
# Processing Record 42 of Set 11 | walvis bay
# Processing Record 43 of Set 11 | broome
# Processing Record 44 of Set 11 | sakakah
# Processing Record 45 of Set 11 | andradina
# Processing Record 46 of Set 11 | lompoc
# Processing Record 47 of Set 11 | nurota
# Processing Record 48 of Set 11 | ovre ardal
# Processing Record 49 of Set 11 | solnechnyy
# Processing Record 50 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 12 | pangody
# Processing Record 2 of Set 12 | dir
# Processing Record 3 of Set 12 | zhezkazgan
# Processing Record 4 of Set 12 | floresta
# Processing Record 5 of Set 12 | westport
# Processing Record 6 of Set 12 | mahdalynivka
# Processing Record 7 of Set 12 | terrace
# Processing Record 8 of Set 12 | ilulissat
# Processing Record 9 of Set 12 | kisangani
# Processing Record 10 of Set 12 | dailly
# Processing Record 11 of Set 12 | svetlaya
# Processing Record 12 of Set 12 | killarney
# Processing Record 13 of Set 12 | horsham
# Processing Record 14 of Set 12 | matola
# Processing Record 15 of Set 12 | kharagauli
# Processing Record 16 of Set 12 | kunya
# Processing Record 17 of Set 12 | chokurdakh
# Processing Record 18 of Set 12 | teul
# City not found. Skipping...
# Processing Record 19 of Set 12 | zemio
# Processing Record 20 of Set 12 | victor harbor
# Processing Record 21 of Set 12 | turukhansk
# Processing Record 22 of Set 12 | ahuimanu
# Processing Record 23 of Set 12 | guiyang
# Processing Record 24 of Set 12 | pitimbu
# Processing Record 25 of Set 12 | wahlstedt
# Processing Record 26 of Set 12 | yenagoa
# Processing Record 27 of Set 12 | san martin
# Processing Record 28 of Set 12 | mitu
# Processing Record 29 of Set 12 | haines junction
# Processing Record 30 of Set 12 | sao sebastiao
# Processing Record 31 of Set 12 | mbaiki
# Processing Record 32 of Set 12 | alugan
# Processing Record 33 of Set 12 | flinders
# Processing Record 34 of Set 12 | mirabad
# Processing Record 35 of Set 12 | taloda
# Processing Record 36 of Set 12 | nemuro
# Processing Record 37 of Set 12 | swansea
# Processing Record 38 of Set 12 | palora
# Processing Record 39 of Set 12 | port macquarie
# Processing Record 40 of Set 12 | jacareacanga
# Processing Record 41 of Set 12 | achisay
# City not found. Skipping...
# Processing Record 42 of Set 12 | mont-dore
# Processing Record 43 of Set 12 | campbell river
# Processing Record 44 of Set 12 | jasper
# Processing Record 45 of Set 12 | greystones
# Processing Record 46 of Set 12 | egvekinot
# Processing Record 47 of Set 12 | kyra
# Processing Record 48 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 49 of Set 12 | birin
# Processing Record 50 of Set 12 | gazimurskiy zavod
# Processing Record 1 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 13 | tuatapere
# Processing Record 3 of Set 13 | olafsvik
# Processing Record 4 of Set 13 | carrboro
# Processing Record 5 of Set 13 | oleksandrivka
# Processing Record 6 of Set 13 | pacific grove
# Processing Record 7 of Set 13 | mangrol
# Processing Record 8 of Set 13 | kevsala
# Processing Record 9 of Set 13 | khandbari
# Processing Record 10 of Set 13 | maarianhamina
# Processing Record 11 of Set 13 | bedong
# Processing Record 12 of Set 13 | qingyuan
# Processing Record 13 of Set 13 | chapais
# Processing Record 14 of Set 13 | yerbogachen
# Processing Record 15 of Set 13 | narsaq
# Processing Record 16 of Set 13 | narasannapeta
# Processing Record 17 of Set 13 | rio grande
# Processing Record 18 of Set 13 | tulcea
# Processing Record 19 of Set 13 | qinzhou
# Processing Record 20 of Set 13 | limulunga
# Processing Record 21 of Set 13 | taganak
# Processing Record 22 of Set 13 | bayaguana
# Processing Record 23 of Set 13 | shetpe
# Processing Record 24 of Set 13 | conde
# Processing Record 25 of Set 13 | safranbolu
# Processing Record 26 of Set 13 | kawhia
# Processing Record 27 of Set 13 | hibbing
# Processing Record 28 of Set 13 | caravelas
# Processing Record 29 of Set 13 | ayutla
# Processing Record 30 of Set 13 | kati
# Processing Record 31 of Set 13 | salalah
# Processing Record 32 of Set 13 | praia
# Processing Record 33 of Set 13 | marion
# Processing Record 34 of Set 13 | teguise
# Processing Record 35 of Set 13 | saint-francois
# Processing Record 36 of Set 13 | jian
# Processing Record 37 of Set 13 | port lincoln
# Processing Record 38 of Set 13 | bordighera
# Processing Record 39 of Set 13 | sept-iles
# Processing Record 40 of Set 13 | kankan
# Processing Record 41 of Set 13 | poronaysk
# Processing Record 42 of Set 13 | antalaha
# Processing Record 43 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 44 of Set 13 | uva
# Processing Record 45 of Set 13 | mandera
# Processing Record 46 of Set 13 | half moon bay
# Processing Record 47 of Set 13 | hamilton
# Processing Record 48 of Set 13 | beidao
# Processing Record 49 of Set 13 | mahaicony
# City not found. Skipping...
# Processing Record 50 of Set 13 | port-gentil
# Processing Record 1 of Set 14 | carutapera
# Processing Record 2 of Set 14 | cam ranh
# Processing Record 3 of Set 14 | atotonilco el alto
# Processing Record 4 of Set 14 | anadyr
# Processing Record 5 of Set 14 | traverse city
# Processing Record 6 of Set 14 | waw
# Processing Record 7 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 14 | dodge city
# Processing Record 9 of Set 14 | sorland
# Processing Record 10 of Set 14 | along
# Processing Record 11 of Set 14 | laguna de perlas
# Processing Record 12 of Set 14 | marshalltown
# Processing Record 13 of Set 14 | duz
# City not found. Skipping...
# Processing Record 14 of Set 14 | turiacu
# Processing Record 15 of Set 14 | campbellton
# Processing Record 16 of Set 14 | bodden town
# Processing Record 17 of Set 14 | san policarpo
# Processing Record 18 of Set 14 | sal rei
# Processing Record 19 of Set 14 | akdepe
# Processing Record 20 of Set 14 | martapura
# Processing Record 21 of Set 14 | yeppoon
# Processing Record 22 of Set 14 | vidalia
# Processing Record 23 of Set 14 | paciran
# Processing Record 24 of Set 14 | cayenne
# Processing Record 25 of Set 14 | darhan
# Processing Record 26 of Set 14 | ciudad bolivar
# Processing Record 27 of Set 14 | bridlington
# Processing Record 28 of Set 14 | swan hill
# Processing Record 29 of Set 14 | alice springs
# Processing Record 30 of Set 14 | otradnoye
# Processing Record 31 of Set 14 | ambon
# Processing Record 32 of Set 14 | manakara
# Processing Record 33 of Set 14 | santo antonio do leverger
# Processing Record 34 of Set 14 | esil
# Processing Record 35 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 36 of Set 14 | port moresby
# Processing Record 37 of Set 14 | lata
# Processing Record 38 of Set 14 | neiafu
# Processing Record 39 of Set 14 | young
# Processing Record 40 of Set 14 | serdobsk
# Processing Record 41 of Set 14 | la grande
# Processing Record 42 of Set 14 | isangel
# Processing Record 43 of Set 14 | ta khmau
# Processing Record 44 of Set 14 | vieques
# Processing Record 45 of Set 14 | padang
# Processing Record 46 of Set 14 | tshela
# Processing Record 47 of Set 14 | ilesha
# Processing Record 48 of Set 14 | namibe
# Processing Record 49 of Set 14 | general pico
# Processing Record 50 of Set 14 | pechenga
# Processing Record 1 of Set 15 | zaraza
# Processing Record 2 of Set 15 | iquique
# Processing Record 3 of Set 15 | muisne
# Processing Record 4 of Set 15 | pathein
# Processing Record 5 of Set 15 | tarata
# Processing Record 6 of Set 15 | ibra
# Processing Record 7 of Set 15 | turbat
# Processing Record 8 of Set 15 | tessalit
# Processing Record 9 of Set 15 | bilecik
# Processing Record 10 of Set 15 | bandarbeyla
# Processing Record 11 of Set 15 | lorengau
# Processing Record 12 of Set 15 | kijang
# Processing Record 13 of Set 15 | suao
# City not found. Skipping...
# Processing Record 14 of Set 15 | batagay-alyta
# Processing Record 15 of Set 15 | alta floresta
# Processing Record 16 of Set 15 | bolshiye chapurniki
# City not found. Skipping...
# Processing Record 17 of Set 15 | paragominas
# Processing Record 18 of Set 15 | roros
# Processing Record 19 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 20 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 21 of Set 15 | palu
# Processing Record 22 of Set 15 | trelew
# Processing Record 23 of Set 15 | anuppur
# Processing Record 24 of Set 15 | hualmay
# Processing Record 25 of Set 15 | goderich
# Processing Record 26 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 27 of Set 15 | omsukchan
# Processing Record 28 of Set 15 | fort-shevchenko
# Processing Record 29 of Set 15 | cimislia
# Processing Record 30 of Set 15 | muros
# Processing Record 31 of Set 15 | taoudenni
# Processing Record 32 of Set 15 | moron
# Processing Record 33 of Set 15 | nizhneudinsk
# Processing Record 34 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 36 of Set 15 | baykit
# Processing Record 37 of Set 15 | nome
# Processing Record 38 of Set 15 | bubaque
# Processing Record 39 of Set 15 | canandaigua
# Processing Record 40 of Set 15 | fare
# Processing Record 41 of Set 15 | siretel
# Processing Record 42 of Set 15 | ksenyevka
# City not found. Skipping...
# Processing Record 43 of Set 15 | sisimiut
# Processing Record 44 of Set 15 | dzerzhinsk
# Processing Record 45 of Set 15 | hokitika
# Processing Record 46 of Set 15 | ketchikan
# Processing Record 47 of Set 15 | jinka
# Processing Record 48 of Set 15 | teguldet
# Processing Record 49 of Set 15 | panaba
# Processing Record 50 of Set 15 | upington
# Processing Record 1 of Set 16 | itaguai
# Processing Record 2 of Set 16 | mazagao
# Processing Record 3 of Set 16 | tondano
# Processing Record 4 of Set 16 | zeya
# Processing Record 5 of Set 16 | prabumulih
# Processing Record 6 of Set 16 | zhicheng
# Processing Record 7 of Set 16 | willmar
# Processing Record 8 of Set 16 | sovetskaya gavan
# Processing Record 9 of Set 16 | esna
# Processing Record 10 of Set 16 | salinas
# Processing Record 11 of Set 16 | bethanien
# Processing Record 12 of Set 16 | usogorsk
# Processing Record 13 of Set 16 | mayskiy
# Processing Record 14 of Set 16 | fandriana
# Processing Record 15 of Set 16 | tarudant
# City not found. Skipping...
# Processing Record 16 of Set 16 | gbadolite
# Processing Record 17 of Set 16 | muravlenko
# Processing Record 18 of Set 16 | zabaykalsk
# Processing Record 19 of Set 16 | arya
# Processing Record 20 of Set 16 | mayo
# Processing Record 21 of Set 16 | roma
# Processing Record 22 of Set 16 | tugolesskiy bor
# Processing Record 23 of Set 16 | marv dasht
# City not found. Skipping...
# Processing Record 24 of Set 16 | jiayuguan
# Processing Record 25 of Set 16 | trujillo
# Processing Record 26 of Set 16 | manhattan
# Processing Record 27 of Set 16 | the pas
# Processing Record 28 of Set 16 | mwene-ditu
# Processing Record 29 of Set 16 | acapulco
# Processing Record 30 of Set 16 | gat
# Processing Record 31 of Set 16 | barbar
# City not found. Skipping...
# Processing Record 32 of Set 16 | verkhoyansk
# Processing Record 33 of Set 16 | aksum
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng Current Description  Max Temp  \
# 0   Bambous Virieux -20.3428   57.7575          light rain     70.21
# 1          Khatanga  71.9667  102.5000           clear sky     69.31
# 2         Busselton -33.6500  115.3333     overcast clouds     51.08
# 3          Ullapool  57.8987   -5.1604     overcast clouds     61.75
# 4      Punta Arenas -53.1500  -70.9167           clear sky     41.11
# 5            Bereda  43.2686   -7.5406       broken clouds     71.42
# 6  Dzhebariki-Khaya  62.2167  135.8000          few clouds     53.22
# 7          Americus  32.0724  -84.2327    scattered clouds     94.05
# 8       Yellowknife  62.4560 -114.3525          few clouds     73.29
# 9           Ushuaia -54.8000  -68.3000       broken clouds     46.06
#
#    Humidity  Cloudiness  Wind Speed Country                 Date
# 0        78          40       12.66      MU  2021-07-31 16:43:44
# 1        36           9       12.80      RU  2021-07-31 16:43:45
# 2        77          90       29.68      AU  2021-07-31 16:43:45
# 3        77          99        5.79      GB  2021-07-31 16:43:45
# 4        60           0       13.80      CL  2021-07-31 16:43:45
# 5        47          71        5.93      ES  2021-07-31 16:43:46
# 6        59          24        3.22      RU  2021-07-31 16:43:46
# 7        67          33        1.01      US  2021-07-31 16:43:46
# 8        68          20        5.75      CA  2021-07-31 16:43:47
# 9        49          75       13.80      AR  2021-07-31 16:43:47

# %%
#Reorder the columns
new_column_order = ["City", "Country","Lat","Lng","Max Temp", "Humidity","Cloudiness","Wind Speed", "Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df.head()
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Bambous Virieux      MU -20.3428   57.7575     70.21        78          40
# 1         Khatanga      RU  71.9667  102.5000     69.31        36           9
# 2        Busselton      AU -33.6500  115.3333     51.08        77          90
# 3         Ullapool      GB  57.8987   -5.1604     61.75        77          99
# 4     Punta Arenas      CL -53.1500  -70.9167     41.11        60           0
#
#    Wind Speed Current Description
# 0       12.66          light rain
# 1       12.80           clear sky
# 2       29.68     overcast clouds
# 3        5.79     overcast clouds
# 4       13.80           clear sky

# %%
# Create the output file (CSV).
output_data_file = (r"C:\\Users\chuba\Class\World_Weather_Analysis\Weather_Database\WeatherPy_Database.csv")

# 8b. Export the City_Data into a csv 
city_data_df.to_csv(output_data_file, index_label="City_ID")
